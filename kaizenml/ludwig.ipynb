# %%
# %pip install -q ludwig
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !wget https://raw.githubusercontent.com/paiml/practical-mlops-book/main/chap05/config.yaml
# !wget https://raw.githubusercontent.com/paiml/practical-mlops-book/main/chap05/reuters-allcats.csv
# Out:
# --2022-06-21 13:40:34--  https://raw.githubusercontent.com/paiml/practical-mlops-book/main/chap05/config.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8002::154, 2606:50c0:8001::154, 2606:50c0:8000::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8002::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 176 [text/plain]
# Saving to: ‘config.yaml.1’
#
# config.yaml.1       100%[===================>]     176  --.-KB/s    in 0s
#
# 2022-06-21 13:40:34 (4.97 MB/s) - ‘config.yaml.1’ saved [176/176]
#
# --2022-06-21 13:40:35--  https://raw.githubusercontent.com/paiml/practical-mlops-book/main/chap05/reuters-allcats.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8002::154, 2606:50c0:8001::154, 2606:50c0:8000::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8002::154|:443... connected.
# ...

# %%
# RUN VIA COLABS or some other optimized compute
# !ludwig experiment --dataset reuters-allcats.csv --config config.yaml
# Out:
# NumExpr defaulting to 4 threads.
# import ray failed with exception: No module named 'ray'
# ███████████████████████
# █ █ █ █  ▜█ █ █ █ █   █
# █ █ █ █ █ █ █ █ █ █ ███
# █ █   █ █ █ █ █ █ █ ▌ █
# █ █████ █ █ █ █ █ █ █ █
# █     █  ▟█     █ █   █
# ███████████████████████
# ludwig v0.5.2 - Experiment
#
#
# ╒════════════════════════╕
# │ EXPERIMENT DESCRIPTION │
# ╘════════════════════════╛
#
# ╒══════════════════╤═══════════════════════════════════════════════════════════════════════════╕
# │ Experiment name  │ experiment                                                                │
# ├──────────────────┼───────────────────────────────────────────────────────────────────────────┤
# │ Model name       │ run                                                                       │
# ├──────────────────┼───────────────────────────────────────────────────────────────────────────┤
# │ Output directory │ /home/matt/projects/mlops/practical-mlops/kaizenml/results/experiment_run │
# ...
